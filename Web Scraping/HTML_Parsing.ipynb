# %%
import Import_HTML_Scripts_Funct as imp_html
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
soup = imp_html.scroll("https://longmontcolorado.gov/events/list/")

# %%
soup.find_all("div", class_="tribe-events-calendar-list__event-date-tag tribe-common-g-col")
# Out:
# [<div class="tribe-events-calendar-list__event-date-tag tribe-common-g-col">
#  <time aria-hidden="true" class="tribe-events-calendar-list__event-date-tag-datetime" datetime="2025-05-19">
#  <span class="tribe-events-calendar-list__event-date-tag-weekday">
#  			Mon		</span>
#  <span class="tribe-events-calendar-list__event-date-tag-daynum tribe-common-h5 tribe-common-h4--min-medium">
#  			19		</span>
#  </time>
#  </div>,
#  <div class="tribe-events-calendar-list__event-date-tag tribe-common-g-col">
#  <time aria-hidden="true" class="tribe-events-calendar-list__event-date-tag-datetime" datetime="2025-05-19">
#  <span class="tribe-events-calendar-list__event-date-tag-weekday">
#  			Mon		</span>
#  <span class="tribe-events-calendar-list__event-date-tag-daynum tribe-common-h5 tribe-common-h4--min-medium">
#  			19		</span>
#  </time>
#  </div>,
#  <div class="tribe-events-calendar-list__event-date-tag tribe-common-g-col">
# ...

# %%
names, dates, times = [[], [], []]

for event in soup.find_all("div", class_="tribe-events-calendar-list__event-date-tag tribe-common-g-col"):
    names.append()
    dates.append()
    times.append()
# Out:
# [<div class="tribe-events-calendar-list__event-date-tag tribe-common-g-col">
#  <time aria-hidden="true" class="tribe-events-calendar-list__event-date-tag-datetime" datetime="2025-05-19">
#  <span class="tribe-events-calendar-list__event-date-tag-weekday">
#  			Mon		</span>
#  <span class="tribe-events-calendar-list__event-date-tag-daynum tribe-common-h5 tribe-common-h4--min-medium">
#  			19		</span>
#  </time>
#  </div>,
#  <div class="tribe-events-calendar-list__event-date-tag tribe-common-g-col">
#  <time aria-hidden="true" class="tribe-events-calendar-list__event-date-tag-datetime" datetime="2025-05-19">
#  <span class="tribe-events-calendar-list__event-date-tag-weekday">
#  			Mon		</span>
#  <span class="tribe-events-calendar-list__event-date-tag-daynum tribe-common-h5 tribe-common-h4--min-medium">
#  			19		</span>
#  </time>
#  </div>,
#  <div class="tribe-events-calendar-list__event-date-tag tribe-common-g-col">
# ...
